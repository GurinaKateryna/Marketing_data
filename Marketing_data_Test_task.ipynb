# %%
import numpy as np
import pandas as pd
import scipy.stats as sps
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
#laod a dataset
df=pd.read_csv('marketing_data.csv')
df.head()
# Out:
#       ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# 1         0     6/15/14        0       464  ...                  7
# 2         1     5/13/14        0       134  ...                  5
# 3         1     5/11/14        0        10  ...                  2
# 4         0      4/8/14        0         6  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %%
#show columns
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ',
#        'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
#show size of dataset
df.shape
# Out:
# (2240, 28)

# %%
#discribe dataset
df.describe()
# Out:
#                  ID   Year_Birth      Kidhome     Teenhome      Recency  \
# count   2240.000000  2240.000000  2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804     0.444196     0.506250    49.109375
# std     3246.662198    11.984069     0.538398     0.544538    28.962453
# min        0.000000  1893.000000     0.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000     0.000000     0.000000    24.000000
# 50%     5458.500000  1970.000000     0.000000     0.000000    49.000000
# 75%     8427.750000  1977.000000     1.000000     1.000000    74.000000
# max    11191.000000  1996.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2240.000000  2240.000000      2240.000000      2240.000000
# mean    303.935714    26.302232       166.950000        37.525446
# std     336.597393    39.773434       225.715373        54.628979
# ...

# %%
#show summ of null in columns
print(df.isnull().sum())
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
#  Income                24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %%
#transform column Income in float type
df.rename(columns={' Income ' : 'Income'}, inplace=True)
df['Income']=df["Income"].str.replace("$","")
df['Income']=df["Income"].str.replace(",","")
df['Income']=df["Income"].str.replace(" ","")
df['Income']=df["Income"].astype(float)
df['Income']
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_5584/624055049.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Income']=df["Income"].str.replace("$","")
# 0       84835.0
# 1       57091.0
# 2       67267.0
# 3       32474.0
# 4       21474.0
#          ...
# 2235    66476.0
# 2236    31056.0
# 2237    46310.0
# 2238    65819.0
# 2239    94871.0
# Name: Income, Length: 2240, dtype: float64

# %%
#show all Income values
plt.title('Income',size=15)
sns.boxplot(x='Income',data=df)
# Out:
# <AxesSubplot:title={'center':'Income'}, xlabel='Income'>

# %%
#describe column Income
df['Income'].isna().sum()
# Out:
# 24

# %%
df['Income'].describe()
# Out:
# count      2216.000000
# mean      52247.251354
# std       25173.076661
# min        1730.000000
# 25%       35303.000000
# 50%       51381.500000
# 75%       68522.000000
# max      666666.000000
# Name: Income, dtype: float64

# %%
#Removing outlier
#replace values in column Income on Nan if values don't in interval [25percentile*1.5,75percentile*1.5] 
for x in ['Income']:
    q75,q25=np.percentile(df.loc[:,x],[75,25])
    intr_qr=q75-q25
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
    df.loc[df[x] < min,x]=np.nan
    df.loc[df[x] > max,x]=np.nan
df.isnull().sum()
df = df.dropna(axis = 0)
sns.boxplot(x=df['Income'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Income'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['Income'].describe()
# Out:
# count      2216.000000
# mean      52247.251354
# std       25173.076661
# min        1730.000000
# 25%       35303.000000
# 50%       51381.500000
# 75%       68522.000000
# max      666666.000000
# Name: Income, dtype: float64

# %%
 
df['Income'].isnull().sum()
# Out:
# 0

# %%
fig, ax = plt.subplots(figsize=(10, 7))
plt.hist(df['Income'])
plt.xlabel('Income')
plt.ylabel('count')
plt.show()

# %%
# %matplotlib inline
# Exploring correlation of features
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),cmap="YlGnBu",annot=True)
plt.show()

# %%
countries = df['Country'].unique()
countries
# Out:
# array(['SP', 'CA', 'US', 'AUS', 'GER', 'IND', 'SA', 'ME'], dtype=object)

# %%
 # show how much responses and complains in such country

# %%
response_comlain=df.groupby('Country').agg(
total_Response = pd.NamedAgg(column = 'Response', aggfunc = 'sum'),
total_complain = pd.NamedAgg(column = 'Complain', aggfunc = 'sum')
)
response_comlain
# Out:
#          total_Response  total_complain
# Country
# AUS                  22               0
# CA                   38               2
# GER                  17               1
# IND                  13               1
# ME                    2               0
# SA                   52               3
# SP                  176              14
# US                   13               0

# %%
fix, ax = plt.subplots(figsize=(15,8))
ax.pie( response_comlain['total_Response'], labels=['AUS','CA','GER','IND','ME','SA','SP','US'],autopct='%1.1f%%',
        shadow=True, startangle=90)
ax.legend()

# %%
fix, ax = plt.subplots(figsize=(15,8))
ax.pie( response_comlain['total_complain'], labels=['AUS','CA','GER','IND','ME','SA','SP','US'],autopct='%1.1f%%',
        shadow=True, startangle=90)
ax.legend()

# %%
#show how purchase of sweets and fruits depend on ammount of teen
sweetsteen=df.groupby(['Teenhome']).agg(
sweetteen = pd.NamedAgg(column = 'MntSweetProducts', aggfunc = 'sum'),
fruitsteen = pd.NamedAgg(column = 'MntFruits', aggfunc = 'sum')
)
sweetsteen
# Out:
#           sweetteen  fruitsteen
# Teenhome
# 0             38482       38246
# 1             20628       19268
# 2               786         891

# %%
#show how purchase of sweets and fruits depend on ammount of child
sweetschild=df.groupby(['Kidhome']).agg(
sweetChild = pd.NamedAgg(column = 'MntSweetProducts', aggfunc = 'sum'),
fruitsChild = pd.NamedAgg(column = 'MntFruits', aggfunc = 'sum')
)
sweetschild
# Out:
#          sweetChild  fruitsChild
# Kidhome
# 0             52078        50551
# 1              7639         7576
# 2               179          278

# %%
#show how purchase of wines,meat and fish depends of marital status
wine=df.groupby(['Marital_Status']).agg(
wines = pd.NamedAgg(column = 'MntWines', aggfunc = 'sum'),
fish = pd.NamedAgg(column = 'MntFishProducts', aggfunc = 'sum'),
meat = pd.NamedAgg(column = 'MntMeatProducts', aggfunc = 'sum'),
)
wine.sort_values(by='wines',ascending=False)
# Out:
#                  wines   fish    meat
# Marital_Status
# Married         256976  30395  137888
# Together        176715  22383   95374
# Single          137217  18262   87064
# Divorced         75364   8130   34848
# Widow            27902   3793   14085
# Absurd             711    411     625
# YOLO               644      8     100
# Alone              554     23      79

# %%
category_names = ['wines', 'fish',
                  'meat']
results = {
    'Married': [258751,30569,138829],
    'Together': [177959, 22615,97500],
    'Single': [138399,18344, 87412],
    'Divorced': [75364, 8130 ,34848],
    'Widow': [28434, 3957, 14575],
    'Absurd': [711, 411, 625],
    'YOLO': [644, 8, 100],
    'Alone': [554, 23, 79]
}


def Marital_Status(results, category_names):
    
    labels = list(results.keys())
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    category_colors = plt.get_cmap('Set1')(
        np.linspace(0.15, 0.85, 8))


    fig, ax = plt.subplots(figsize=(20, 10))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names,  category_colors)):
        widths = data[:, i]
        starts = data_cum[:, i] - widths
        rects = ax.barh(labels, widths, left=starts, height=0.5,
                        label=colname, color=color)

        r, g, b, _ = color
        text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
        ax.bar_label(rects, label_type='center', color=text_color)
    ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 1),
              loc='lower left', fontsize='small')

    return fig, ax


Marital_Status(results, category_names)
plt.show()

# %%
# count an age of customers
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2216 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2216 non-null   int64
#  1   Year_Birth           2216 non-null   int64
#  2   Education            2216 non-null   object
#  3   Marital_Status       2216 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2216 non-null   int64
#  6   Teenhome             2216 non-null   int64
#  7   Dt_Customer          2216 non-null   datetime64[ns]
#  8   Recency              2216 non-null   int64
#  9   MntWines             2216 non-null   int64
#  10  MntFruits            2216 non-null   int64
#  11  MntMeatProducts      2216 non-null   int64
#  12  MntFishProducts      2216 non-null   int64
#  13  MntSweetProducts     2216 non-null   int64
#  14  MntGoldProds         2216 non-null   int64
# ...

# %%
from datetime import date
df['Age']  = date.today().year - df['Year_Birth']
df.head()
# Out:
#       ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  NumWebVisitsMonth  AcceptedCmp3  \
# 0  2014-06-16        0       189  ...                  1             0
# 1  2014-06-15        0       464  ...                  5             0
# 2  2014-05-13        0       134  ...                  2             0
# 3  2014-05-11        0        10  ...                  7             0
# 4  2014-04-08        0         6  ...                  7             1
#
#    AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain  \
# ...

# %%
#show all age of customers
fig, ax = plt.subplots(figsize=(15, 10),dpi=130)
sns.countplot(x=df['Age'],color = 'red'
            
             )
for p in ax.patches: 
    ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))

# %%
df['Age'].describe()
# Out:
# count    2216.000000
# mean       53.179603
# std        11.985554
# min        26.000000
# 25%        45.000000
# 50%        52.000000
# 75%        63.000000
# max       129.000000
# Name: Age, dtype: float64

# %%
# removing outliers
df= df[df['Age'] < 100] 
df['Age'].describe()
# Out:
# count    2213.000000
# mean       53.082693
# std        11.700216
# min        26.000000
# 25%        45.000000
# 50%        52.000000
# 75%        63.000000
# max        82.000000
# Name: Age, dtype: float64

# %%
#count total amount of purchase for each id
df['Total'] = df['MntWines']+df['MntFruits']+df['MntMeatProducts']+df['MntFishProducts']+df['MntSweetProducts']+df['MntGoldProds']
df.head()
# Out:
#       ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  AcceptedCmp3  AcceptedCmp4  \
# 0  2014-06-16        0       189  ...             0             0
# 1  2014-06-15        0       464  ...             0             0
# 2  2014-05-13        0       134  ...             0             0
# 3  2014-05-11        0        10  ...             0             0
# 4  2014-04-08        0         6  ...             1             0
#
#    AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain  Country  Age  \
# ...

# %%
#show how total purchase depends in income 
sns.scatterplot(x=df['Income'],y=df['Total'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Total'>

# %%
#show how age depends in income 
sns.scatterplot(x=df['Age'],y=df['Income'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Income'>

# %%
df['Total_Purchase']= df['NumWebPurchases']+df['NumCatalogPurchases']+df['NumStorePurchases']+df['NumDealsPurchases']
df.head()
# Out:
#       ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  AcceptedCmp4  AcceptedCmp5  \
# 0  2014-06-16        0       189  ...             0             0
# 1  2014-06-15        0       464  ...             0             0
# 2  2014-05-13        0       134  ...             0             0
# 3  2014-05-11        0        10  ...             0             0
# 4  2014-04-08        0         6  ...             0             0
#
#    AcceptedCmp1  AcceptedCmp2  Response  Complain  Country  Age  Total  \
# ...

# %%
df['StorePurch'] = (df['NumStorePurchases']/df['Total_Purchase'])*100

# %%
df['othersPurch']=100-df['StorePurch']
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  AcceptedCmp1  \
# 0            0  2014-06-16        0       189  ...             0
# ...

# %%
#show how many purchase were in store or other chanel
fig, ax = plt.subplots(figsize=(10, 7))
ax.hist(df['othersPurch'],alpha=.5,label='othersPurch')
ax.hist(df['StorePurch'],alpha=.5,label='StorePurch')
ax.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#show revenue in different categories
revenue = pd.DataFrame(df.iloc[:,9:15].sum(),columns=['revenue']).reset_index()
revenue
# Out:
#               index  revenue
# 0          MntWines   675305
# 1         MntFruits    58255
# 2   MntMeatProducts   369488
# 3   MntFishProducts    83287
# 4  MntSweetProducts    59828
# 5      MntGoldProds    97176

# %%
plt.figure(figsize=(11,7))
plt.title("Revenue By Products")
yyx= sns.barplot(x='index',y='revenue',data=revenue);
plt.xlabel('Products')
plt.ylabel('Revenue')
for p in yyx.patches: 
    yyx.annotate('{:}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01)) 
plt.show()

# %%
#show education level in dataset
plt.figure(figsize=(10,5))
ec = sns.countplot(x='Education',  data=df)
for p in ec.patches: 
    ec.annotate('{:}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01)) 
plt.show()
